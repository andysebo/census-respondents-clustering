# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt #pyplot is a speciic submodule that contains the commands like .plot() 

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.plot(x, y)
plt.title("If you see a sine wave we good")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
